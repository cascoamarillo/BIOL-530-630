# %% [markdown]
# # Lab10 - Bioinformatics Algorithms
#
# # Gene prediction - ORF finding

# %% [markdown]
# ## Background
# An open reading frame (ORF) is a portion of a DNA sequence that does not include a stop codon (which functions as a stop signal). A codon is a DNA or RNA sequence of three nucleotides (a trinucleotide) that forms a unit of genomic information encoding a particular amino acid or signaling the termination of protein synthesis (stop codon).
# A prokaryotic gene typically begins with a start codon (eg. ATG). Gene ends with one of the three stops codon (eg. TAG, TAA, or TGA).
#
# ## Discussion10
#
# We will explore the bacterial genome of bacilus subtilis (NC_000964.3.) with two approaches:
#
# 1- Regular ORF finder function (jupyter book below)
#
# 2- Gene prediction program using HMMs (GeneMarkS-2)
# download: https://genemark.bme.gatech.edu/license_download.cgi
# online: https://genemark.bme.gatech.edu/genemarks2.cgi
#
# The genome fasta file will be in MyCourses under Content > Labs to make sure everyone has the same version. If you want to know more about the Bsubtilis genome:
# https://www.ncbi.nlm.nih.gov/datasets/genome/GCF_000009045.1/
#
# And we will use the UCSC genome browser of microbial genomes for visualtization of our results:
# https://microbes.ucsc.edu/
#
# For  discussion10:
# 1. Understand the basic ORF rules.
# 2. Implement ORF finder using both strands, with stop, start codons and a minimun gene length.
# 3. Get the GFF3 file and save it locally.
# 4. Run GeneMarkS-2 with the bacterial genome. Make sure you select GFF3 as output format.
# 5. Upload both annotations in the UCSC browser (custom tracks), and take a sceenshot or two with your results and reflections. Send it as PDF to myCourses.

# %% [markdown]
# ## GeneMarkS-2 line to run in your computer (not here in the jupyter notebook)

# %%
perl gms2.pl --seq Bsubtilis-NC_000964.3.fa --genome-type bacteria --output Bsubtilis.gff3 --format gff3

# %% [markdown]
# ## In Oedipus:
# Copy folder "Lab10" with the bacteria genome in YOUR direcory

# %%
cp -R /mnt/classes/biol_530_630/data/Lab10/ ~/

cd ~/Lab10

# %% [markdown]
# ### GeneMark is installed in
#  /mnt/classes/biol_530_630/bioware/gms2_linux_64/
#  You are going to need the full path. But first, you need to copy the Genemark key in your home directory:

# %%
cp /mnt/classes/biol_530_630/bioware/gms2_linux_64/.gmhmmp2_key ~/

# %%
/mnt/classes/biol_530_630/bioware/gms2_linux_64/gms2.pl --seq Bsubtilis-NC_000964.3.fa --genome-type bacteria --output Bsubtilis.gff3 --format gff3

# %% [markdown]
# # Now the jupyter notebook with the ORF finder ("ORF-Finder")

# %% [markdown]
#  ## Import necessary libraries

# %%
from Bio import SeqIO
from Bio.Seq import Seq
import pandas as pd

# %% [markdown]
# ## Define start and stop codons

# %%
start_codon = 'ATG'
stop_codons = ['TAA', 'TAG', 'TGA']

# %% [markdown]
#  ## Function to find ORFs in all six reading frames

# %%
def find_orfs_in_six_frames(sequence, min_gene_length=250):
    orfs = []
    
    # Analyze both the sense and antisense strands
    for strand, nuc in [(+1, sequence), (-1, sequence.reverse_complement())]:
        seq_len = len(nuc)
        for frame in range(3):
            protein = []
            start_pos = None
            
            # Scan in each frame
            for i in range(frame, seq_len - 2, 3):
                codon = str(nuc[i:i+3])
                
                if codon == start_codon and not protein:
                    protein = [codon]
                    start_pos = i if strand == 1 else seq_len - i - 3  # Adjust for strand
                
                elif protein:
                    protein.append(codon)
                    if codon in stop_codons:
                        if len(protein) * 3 >= min_gene_length:
                            end_pos = i + 3 if strand == 1 else seq_len - i
                            orfs.append({
                                "strand": strand,
                                "start": start_pos + 1,  # Convert to 1-based indexing
                                "end": end_pos,
                                "length": len(protein) * 3
                            })
                        protein = []
    return orfs

# %% [markdown]
#  ## Load sequence from a FASTA file

# %%
sequence_file = "Bsubtilis-NC_000964.3.fa"  # Replace with your file path
record = SeqIO.read(sequence_file, "fasta")
sequence = record.seq

# %% [markdown]
# ## Find ORFs

# %%
orfs = find_orfs_in_six_frames(sequence)

# %% [markdown]
# ## Convert results to DataFrame with strand as "+" or "-"

# %%
orfs_df = pd.DataFrame(orfs)
orfs_df['strand'] = orfs_df['strand'].apply(lambda x: '+' if x == 1 else '-')
orfs_df['type'] = 'gene'
orfs_df['score'] = '.'
orfs_df['phase'] = '.'
orfs_df['source'] = 'GeneFinder'
orfs_df['seqid'] = record.id
orfs_df['unique_id'] = [f"{i+1}-{length}" for i, length in enumerate(orfs_df['length'])]

# Ensure start < end for all entries, regardless of strand
orfs_df['start'], orfs_df['end'] = zip(*orfs_df.apply(
    lambda row: (min(row['start'], row['end']), max(row['start'], row['end'])), axis=1))

# Rearrange columns for GFF3 format
orfs_df = orfs_df[['seqid', 'source', 'type', 'start', 'end', 'score', 'strand', 'phase', 'unique_id']]

# %% [markdown]
# ## Save ORFs to GFF3 format

# %%
orfs_df.to_csv("output_genes.gff3", sep='\t', header=False, index=False)
print("Gene locations saved to output_genes.gff3")
# Out:
# Gene locations saved to output_genes.gff3

# %% [markdown]
# ##Check gff3 file here

# %%
print(orfs_df.to_string(index=False, header=False))
# Out:
# chr GeneFinder gene    1816    3075 . + .     1-1260
# chr GeneFinder gene    4867    6783 . + .     2-1917
# chr GeneFinder gene    6994    9459 . + .     3-2466
# chr GeneFinder gene   14038   14376 . + .      4-339
# chr GeneFinder gene   16888   17220 . + .      5-333
# chr GeneFinder gene   25852   26337 . + .      6-486
# chr GeneFinder gene   28867   29463 . + .      7-597
# chr GeneFinder gene   31474   31728 . + .      8-255
# chr GeneFinder gene   35845   36459 . + .      9-615
# chr GeneFinder gene   36478   37638 . + .    10-1161
# chr GeneFinder gene   37720   39162 . + .    11-1443
# chr GeneFinder gene   39871   40200 . + .     12-330
# chr GeneFinder gene   40306   40653 . + .     13-348
# chr GeneFinder gene   42598   42858 . + .     14-261
# chr GeneFinder gene   43921   44799 . + .     15-879
# chr GeneFinder gene   45796   46134 . + .     16-339
# chr GeneFinder gene   57745   58698 . + .     17-954
# chr GeneFinder gene   58771   59397 . + .     18-627
# chr GeneFinder gene   60430   63963 . + .    19-3534
# chr GeneFinder gene   64063   64635 . + .     20-573
# chr GeneFinder gene   68515   69150 . + .     21-636
# chr GeneFinder gene   74887   76347 . + .    22-1461
# chr GeneFinder gene   76984   78897 . + .    23-1914
# chr GeneFinder gene   82753   84276 . + .    24-1524
# chr GeneFinder gene   84874   85755 . + .     25-882
# chr GeneFinder gene   86587   86949 . + .     26-363
# chr GeneFinder gene   87616   88635 . + .    27-1020
# chr GeneFinder gene  102484  103575 . + .    28-1092
# chr GeneFinder gene  106096  107472 . + .    29-1377
# chr GeneFinder gene  107476  108558 . + .    30-1083
# chr GeneFinder gene  109789  110487 . + .     31-699
# chr GeneFinder gene  118696  119016 . + .     32-321
# chr GeneFinder gene  120061  120561 . + .     33-501
# chr GeneFinder gene  120592  120978 . + .     34-387
# chr GeneFinder gene  129334  129588 . + .     35-255
# chr GeneFinder gene  130684  132762 . + .    36-2079
# chr GeneFinder gene  135364  135672 . + .     37-309
# chr GeneFinder gene  135712  136341 . + .     38-630
# chr GeneFinder gene  136369  136992 . + .     39-624
# chr GeneFinder gene  137311  138144 . + .     40-834
# chr GeneFinder gene  138202  138480 . + .     41-279
# chr GeneFinder gene  140857  141168 . + .     42-312
# chr GeneFinder gene  142387  142941 . + .     43-555
# chr GeneFinder gene  144085  144525 . + .     44-441
# chr GeneFinder gene  146527  147273 . + .     45-747
# chr GeneFinder gene  147973  148338 . + .     46-366
# chr GeneFinder gene  149953  150315 . + .     47-363
# chr GeneFinder gene  151303  152133 . + .     48-831
# chr GeneFinder gene  156109  156552 . + .     49-444
# chr GeneFinder gene  167695  167949 . + .     50-255
# chr GeneFinder gene  175543  175881 . + .     51-339
# chr GeneFinder gene  196186  197034 . + .     52-849
# chr GeneFinder gene  206941  209556 . + .    53-2616
# chr GeneFinder gene  211429  211731 . + .     54-303
# chr GeneFinder gene  215404  216894 . + .    55-1491
# chr GeneFinder gene  216913  217632 . + .     56-720
# chr GeneFinder gene  218581  218880 . + .     57-300
# chr GeneFinder gene  219607  220032 . + .     58-426
# chr GeneFinder gene  220279  221256 . + .     59-978
# chr GeneFinder gene  221926  222912 . + .     60-987
# chr GeneFinder gene  225064  226248 . + .    61-1185
# chr GeneFinder gene  229525  230778 . + .    62-1254
# chr GeneFinder gene  237088  237363 . + .     63-276
# chr GeneFinder gene  243892  245046 . + .    64-1155
# chr GeneFinder gene  245338  245595 . + .     65-258
# chr GeneFinder gene  246094  246492 . + .     66-399
# chr GeneFinder gene  246658  247548 . + .     67-891
# chr GeneFinder gene  247762  248277 . + .     68-516
# chr GeneFinder gene  248749  249540 . + .     69-792
# chr GeneFinder gene  249595  249873 . + .     70-279
# chr GeneFinder gene  249943  251319 . + .    71-1377
# chr GeneFinder gene  252514  253482 . + .     72-969
# chr GeneFinder gene  253522  253818 . + .     73-297
# chr GeneFinder gene  257791  258498 . + .     74-708
# chr GeneFinder gene  258532  258807 . + .     75-276
# chr GeneFinder gene  266719  267663 . + .     76-945
# chr GeneFinder gene  268840  270312 . + .    77-1473
# chr GeneFinder gene  277342  278280 . + .     78-939
# chr GeneFinder gene  278365  279057 . + .     79-693
# chr GeneFinder gene  282379  282897 . + .     80-519
# chr GeneFinder gene  283003  283734 . + .     81-732
# chr GeneFinder gene  284011  285762 . + .    82-1752
# chr GeneFinder gene  286048  286776 . + .     83-729
# chr GeneFinder gene  293008  293280 . + .     84-273
# chr GeneFinder gene  308332  309291 . + .     85-960
# chr GeneFinder gene  310000  310842 . + .     86-843
# chr GeneFinder gene  313180  313974 . + .     87-795
# chr GeneFinder gene  317725  318927 . + .    88-1203
# chr GeneFinder gene  321013  322269 . + .    89-1257
# chr GeneFinder gene  323119  324000 . + .     90-882
# chr GeneFinder gene  325327  326772 . + .    91-1446
# chr GeneFinder gene  327049  327477 . + .     92-429
# chr GeneFinder gene  334762  335259 . + .     93-498
# chr GeneFinder gene  335329  336090 . + .     94-762
# chr GeneFinder gene  337180  337470 . + .     95-291
# chr GeneFinder gene  342538  343494 . + .     96-957
# chr GeneFinder gene  344605  345462 . + .     97-858
# chr GeneFinder gene  348724  349959 . + .    98-1236
# chr GeneFinder gene  352858  353868 . + .    99-1011
# chr GeneFinder gene  357403  357879 . + .    100-477
# chr GeneFinder gene  365170  365754 . + .    101-585
# chr GeneFinder gene  381271  381576 . + .    102-306
# chr GeneFinder gene  402388  403116 . + .    103-729
# chr GeneFinder gene  403240  403605 . + .    104-366
# chr GeneFinder gene  406402  406668 . + .    105-267
# chr GeneFinder gene  412531  413154 . + .    106-624
# chr GeneFinder gene  413635  414072 . + .    107-438
# chr GeneFinder gene  415660  416001 . + .    108-342
# chr GeneFinder gene  416041  416637 . + .    109-597
# chr GeneFinder gene  425491  425745 . + .    110-255
# chr GeneFinder gene  426367  427260 . + .    111-894
# chr GeneFinder gene  433315  434262 . + .    112-948
# chr GeneFinder gene  441538  442881 . + .   113-1344
# chr GeneFinder gene  451618  452739 . + .   114-1122
# chr GeneFinder gene  452758  453894 . + .   115-1137
# chr GeneFinder gene  459049  459822 . + .    116-774
# chr GeneFinder gene  463405  463677 . + .    117-273
# chr GeneFinder gene  466042  466944 . + .    118-903
# chr GeneFinder gene  469426  470937 . + .   119-1512
# chr GeneFinder gene  471709  472569 . + .    120-861
# chr GeneFinder gene  472585  473088 . + .    121-504
# chr GeneFinder gene  473803  474225 . + .    122-423
# chr GeneFinder gene  475798  476493 . + .    123-696
# chr GeneFinder gene  480013  480864 . + .    124-852
# chr GeneFinder gene  488308  488763 . + .    125-456
# chr GeneFinder gene  488830  490554 . + .   126-1725
# chr GeneFinder gene  494506  494877 . + .    127-372
# chr GeneFinder gene  503854  504594 . + .    128-741
# chr GeneFinder gene  506866  507738 . + .    129-873
# chr GeneFinder gene  513283  514764 . + .   130-1482
# chr GeneFinder gene  515710  516075 . + .    131-366
# chr GeneFinder gene  516394  517257 . + .    132-864
# chr GeneFinder gene  517372  518541 . + .   133-1170
# chr GeneFinder gene  520606  521007 . + .    134-402
# chr GeneFinder gene  522088  522417 . + .    135-330
# chr GeneFinder gene  522844  523650 . + .    136-807
# chr GeneFinder gene  524782  525222 . + .    137-441
# chr GeneFinder gene  533332  534780 . + .   138-1449
# chr GeneFinder gene  536380  536670 . + .    139-291
# chr GeneFinder gene  543331  543654 . + .    140-324
# chr GeneFinder gene  545026  545532 . + .    141-507
# chr GeneFinder gene  547450  548481 . + .   142-1032
# chr GeneFinder gene  548722  549651 . + .    143-930
# chr GeneFinder gene  552616  553158 . + .    144-543
# chr GeneFinder gene  553711  554475 . + .    145-765
# chr GeneFinder gene  568345  568938 . + .    146-594
# chr GeneFinder gene  572974  573399 . + .    147-426
# chr GeneFinder gene  574678  575562 . + .    148-885
# chr GeneFinder gene  579541  579876 . + .    149-336
# chr GeneFinder gene  579898  581196 . + .   150-1299
# chr GeneFinder gene  585847  586548 . + .    151-702
# chr GeneFinder gene  589717  591891 . + .   152-2175
# chr GeneFinder gene  598729  599067 . + .    153-339
# chr GeneFinder gene  600079  600366 . + .    154-288
# chr GeneFinder gene  607408  607710 . + .    155-303
# chr GeneFinder gene  609388  612045 . + .   156-2658
# chr GeneFinder gene  615871  616545 . + .    157-675
# chr GeneFinder gene  616672  617934 . + .   158-1263
# chr GeneFinder gene  621811  622218 . + .    159-408
# chr GeneFinder gene  623626  623898 . + .    160-273
# chr GeneFinder gene  625780  626037 . + .    161-258
# chr GeneFinder gene  628699  630027 . + .   162-1329
# chr GeneFinder gene  639484  639822 . + .    163-339
# chr GeneFinder gene  643258  644298 . + .   164-1041
# chr GeneFinder gene  646582  647094 . + .    165-513
# chr GeneFinder gene  658852  659124 . + .    166-273
# chr GeneFinder gene  659608  660564 . + .    167-957
# chr GeneFinder gene  661630  663027 . + .   168-1398
# chr GeneFinder gene  663601  663936 . + .    169-336
# chr GeneFinder gene  670087  671049 . + .    170-963
# chr GeneFinder gene  671152  671928 . + .    171-777
# chr GeneFinder gene  679390  679761 . + .    172-372
# chr GeneFinder gene  685561  685827 . + .    173-267
# chr GeneFinder gene  685834  686145 . + .    174-312
# chr GeneFinder gene  686962  687834 . + .    175-873
# chr GeneFinder gene  689146  690342 . + .   176-1197
# chr GeneFinder gene  690364  692577 . + .   177-2214
# chr GeneFinder gene  692740  694281 . + .   178-1542
# chr GeneFinder gene  702319  702573 . + .    179-255
# chr GeneFinder gene  703237  705465 . + .   180-2229
# chr GeneFinder gene  708010  708597 . + .    181-588
# chr GeneFinder gene  712834  713268 . + .    182-435
# chr GeneFinder gene  716431  716745 . + .    183-315
# chr GeneFinder gene  724987  725997 . + .   184-1011
# chr GeneFinder gene  726916  727569 . + .    185-654
# chr GeneFinder gene  732916  736113 . + .   186-3198
# chr GeneFinder gene  742939  744738 . + .   187-1800
# chr GeneFinder gene  753265  753702 . + .    188-438
# chr GeneFinder gene  753784  754401 . + .    189-618
# chr GeneFinder gene  754480  754923 . + .    190-444
# chr GeneFinder gene  756100  756402 . + .    191-303
# chr GeneFinder gene  757111  757653 . + .    192-543
# chr GeneFinder gene  758719  760452 . + .   193-1734
# chr GeneFinder gene  761905  762945 . + .   194-1041
# chr GeneFinder gene  765838  768123 . + .   195-2286
# chr GeneFinder gene  774799  776790 . + .   196-1992
# chr GeneFinder gene  782062  782949 . + .    197-888
# chr GeneFinder gene  783568  783906 . + .    198-339
# chr GeneFinder gene  784381  785076 . + .    199-696
# chr GeneFinder gene  789544  789882 . + .    200-339
# chr GeneFinder gene  790318  791427 . + .   201-1110
# chr GeneFinder gene  792682  795867 . + .   202-3186
# chr GeneFinder gene  798469  799233 . + .    203-765
# chr GeneFinder gene  799402  800208 . + .    204-807
# chr GeneFinder gene  801313  802350 . + .   205-1038
# chr GeneFinder gene  802405  803286 . + .    206-882
# chr GeneFinder gene  805807  806064 . + .    207-258
# chr GeneFinder gene  807082  808548 . + .   208-1467
# chr GeneFinder gene  809557  811446 . + .   209-1890
# chr GeneFinder gene  812149  812562 . + .    210-414
# chr GeneFinder gene  814642  814980 . + .    211-339
# chr GeneFinder gene  815206  815475 . + .    212-270
# chr GeneFinder gene  820822  822330 . + .   213-1509
# chr GeneFinder gene  823462  823758 . + .    214-297
# chr GeneFinder gene  823810  824283 . + .    215-474
# chr GeneFinder gene  824284  824568 . + .    216-285
# chr GeneFinder gene  825685  825969 . + .    217-285
# chr GeneFinder gene  827455  827802 . + .    218-348
# chr GeneFinder gene  830044  830343 . + .    219-300
# chr GeneFinder gene  830725  831132 . + .    220-408
# chr GeneFinder gene  834070  834339 . + .    221-270
# chr GeneFinder gene  836824  837744 . + .    222-921
# chr GeneFinder gene  847846  848109 . + .    223-264
# chr GeneFinder gene  862492  862812 . + .    224-321
# chr GeneFinder gene  871288  871581 . + .    225-294
# chr GeneFinder gene  872425  873288 . + .    226-864
# chr GeneFinder gene  873655  873972 . + .    227-318
# chr GeneFinder gene  875428  875694 . + .    228-267
# chr GeneFinder gene  887431  887805 . + .    229-375
# chr GeneFinder gene  891421  892200 . + .    230-780
# chr GeneFinder gene  893470  893739 . + .    231-270
# chr GeneFinder gene  901555  902496 . + .    232-942
# chr GeneFinder gene  902506  903687 . + .   233-1182
# chr GeneFinder gene  903805  905013 . + .   234-1209
# chr GeneFinder gene  910840  911928 . + .   235-1089
# chr GeneFinder gene  913924  914460 . + .    236-537
# chr GeneFinder gene  915358  915642 . + .    237-285
# chr GeneFinder gene  916417  916722 . + .    238-306
# chr GeneFinder gene  920836  921126 . + .    239-291
# chr GeneFinder gene  921472  922503 . + .   240-1032
# chr GeneFinder gene  922618  923499 . + .    241-882
# chr GeneFinder gene  923587  924171 . + .    242-585
# chr GeneFinder gene  925543  926427 . + .    243-885
# chr GeneFinder gene  930124  930585 . + .    244-462
# chr GeneFinder gene  931879  934464 . + .   245-2586
# chr GeneFinder gene  935656  936765 . + .   246-1110
# chr GeneFinder gene  937879  938154 . + .    247-276
# chr GeneFinder gene  938731  939261 . + .    248-531
# chr GeneFinder gene  939322  941091 . + .   249-1770
# chr GeneFinder gene  943891  944364 . + .    250-474
# chr GeneFinder gene  945520  946404 . + .    251-885
# chr GeneFinder gene  955822  956073 . + .    252-252
# chr GeneFinder gene  962179  963177 . + .    253-999
# chr GeneFinder gene  964021  965157 . + .   254-1137
# chr GeneFinder gene  970273  970617 . + .    255-345
# chr GeneFinder gene  971374  972087 . + .    256-714
# chr GeneFinder gene  973012  975051 . + .   257-2040
# chr GeneFinder gene  979396  979926 . + .    258-531
# chr GeneFinder gene  979939  980313 . + .    259-375
# chr GeneFinder gene  980431  981234 . + .    260-804
# chr GeneFinder gene  981604  982302 . + .    261-699
# chr GeneFinder gene  984892  985731 . + .    262-840
# chr GeneFinder gene  987052  988377 . + .   263-1326
# chr GeneFinder gene  991324  995001 . + .   264-3678
# chr GeneFinder gene  996643  997038 . + .    265-396
# chr GeneFinder gene 1003483 1003734 . + .    266-252
# chr GeneFinder gene 1006774 1008519 . + .   267-1746
# chr GeneFinder gene 1009804 1010448 . + .    268-645
# chr GeneFinder gene 1011427 1011750 . + .    269-324
# chr GeneFinder gene 1012633 1012980 . + .    270-348
# chr GeneFinder gene 1021057 1022157 . + .   271-1101
# chr GeneFinder gene 1027738 1028202 . + .    272-465
# chr GeneFinder gene 1031395 1031994 . + .    273-600
# chr GeneFinder gene 1041958 1042842 . + .    274-885
# chr GeneFinder gene 1045318 1047075 . + .   275-1758
# chr GeneFinder gene 1049311 1049661 . + .    276-351
# chr GeneFinder gene 1050904 1051338 . + .    277-435
# chr GeneFinder gene 1051387 1051665 . + .    278-279
# chr GeneFinder gene 1051930 1052301 . + .    279-372
# chr GeneFinder gene 1053520 1054653 . + .   280-1134
# chr GeneFinder gene 1061443 1062258 . + .    281-816
# chr GeneFinder gene 1063480 1064739 . + .   282-1260
# chr GeneFinder gene 1068928 1069986 . + .   283-1059
# chr GeneFinder gene 1072768 1073109 . + .    284-342
# chr GeneFinder gene 1079422 1080132 . + .    285-711
# chr GeneFinder gene 1081468 1081821 . + .    286-354
# chr GeneFinder gene 1088191 1089609 . + .   287-1419
# chr GeneFinder gene 1096570 1096917 . + .    288-348
# chr GeneFinder gene 1098412 1099146 . + .    289-735
# chr GeneFinder gene 1099159 1100154 . + .    290-996
# chr GeneFinder gene 1100980 1102521 . + .   291-1542
# chr GeneFinder gene 1103104 1104384 . + .   292-1281
# chr GeneFinder gene 1106524 1107516 . + .    293-993
# chr GeneFinder gene 1107658 1108704 . + .   294-1047
# chr GeneFinder gene 1112842 1113156 . + .    295-315
# chr GeneFinder gene 1114192 1114458 . + .    296-267
# chr GeneFinder gene 1115767 1116555 . + .    297-789
# chr GeneFinder gene 1119469 1119879 . + .    298-411
# chr GeneFinder gene 1122154 1122681 . + .    299-528
# chr GeneFinder gene 1122862 1124361 . + .   300-1500
# chr GeneFinder gene 1125049 1125351 . + .    301-303
# chr GeneFinder gene 1135210 1135587 . + .    302-378
# chr GeneFinder gene 1136182 1139820 . + .   303-3639
# chr GeneFinder gene 1143709 1144752 . + .   304-1044
# chr GeneFinder gene 1148155 1148457 . + .    305-303
# chr GeneFinder gene 1152244 1153149 . + .    306-906
# chr GeneFinder gene 1153789 1156473 . + .   307-2685
# chr GeneFinder gene 1162258 1163130 . + .    308-873
# chr GeneFinder gene 1163653 1163931 . + .    309-279
# chr GeneFinder gene 1164616 1165398 . + .    310-783
# chr GeneFinder gene 1166737 1168191 . + .   311-1455
# chr GeneFinder gene 1172608 1173336 . + .    312-729
# chr GeneFinder gene 1176073 1176360 . + .    313-288
# chr GeneFinder gene 1179427 1179690 . + .    314-264
# chr GeneFinder gene 1184851 1185588 . + .    315-738
# chr GeneFinder gene 1192807 1194288 . + .   316-1482
# chr GeneFinder gene 1198099 1199256 . + .   317-1158
# chr GeneFinder gene 1209862 1210176 . + .    318-315
# chr GeneFinder gene 1212460 1213449 . + .    319-990
# chr GeneFinder gene 1213537 1214028 . + .    320-492
# chr GeneFinder gene 1216210 1217121 . + .    321-912
# chr GeneFinder gene 1217326 1218078 . + .    322-753
# chr GeneFinder gene 1219849 1221486 . + .   323-1638
# chr GeneFinder gene 1223626 1224531 . + .    324-906
# chr GeneFinder gene 1226938 1227516 . + .    325-579
# chr GeneFinder gene 1227697 1228092 . + .    326-396
# chr GeneFinder gene 1229068 1229724 . + .    327-657
# chr GeneFinder gene 1237003 1237641 . + .    328-639
# chr GeneFinder gene 1237660 1238460 . + .    329-801
# chr GeneFinder gene 1243735 1244844 . + .   330-1110
# chr GeneFinder gene 1245808 1246818 . + .   331-1011
# chr GeneFinder gene 1246837 1247652 . + .    332-816
# chr GeneFinder gene 1247755 1248564 . + .    333-810
# chr GeneFinder gene 1250119 1250397 . + .    334-279
# chr GeneFinder gene 1251313 1251612 . + .    335-300
# chr GeneFinder gene 1252258 1252533 . + .    336-276
# chr GeneFinder gene 1254508 1254777 . + .    337-270
# chr GeneFinder gene 1258492 1259613 . + .   338-1122
# chr GeneFinder gene 1265887 1266348 . + .    339-462
# chr GeneFinder gene 1267129 1267413 . + .    340-285
# chr GeneFinder gene 1268275 1268592 . + .    341-318
# chr GeneFinder gene 1274692 1275639 . + .    342-948
# chr GeneFinder gene 1277686 1278165 . + .    343-480
# chr GeneFinder gene 1280560 1280850 . + .    344-291
# chr GeneFinder gene 1285585 1288548 . + .   345-2964
# chr GeneFinder gene 1290523 1290789 . + .    346-267
# chr GeneFinder gene 1292557 1293735 . + .   347-1179
# chr GeneFinder gene 1294114 1294950 . + .    348-837
# chr GeneFinder gene 1297726 1298223 . + .    349-498
# chr GeneFinder gene 1300432 1301871 . + .   350-1440
# chr GeneFinder gene 1303705 1304436 . + .    351-732
# chr GeneFinder gene 1306015 1306311 . + .    352-297
# chr GeneFinder gene 1307446 1308714 . + .   353-1269
# chr GeneFinder gene 1308802 1309803 . + .   354-1002
# chr GeneFinder gene 1311739 1312812 . + .   355-1074
# chr GeneFinder gene 1313353 1313631 . + .    356-279
# chr GeneFinder gene 1317601 1318488 . + .    357-888
# chr GeneFinder gene 1319011 1319613 . + .    358-603
# chr GeneFinder gene 1322014 1322850 . + .    359-837
# chr GeneFinder gene 1324471 1324980 . + .    360-510
# chr GeneFinder gene 1325890 1327191 . + .   361-1302
# chr GeneFinder gene 1327195 1328682 . + .   362-1488
# chr GeneFinder gene 1331245 1331730 . + .    363-486
# chr GeneFinder gene 1331743 1332183 . + .    364-441
# chr GeneFinder gene 1333804 1334247 . + .    365-444
# chr GeneFinder gene 1340932 1341357 . + .    366-426
# chr GeneFinder gene 1343230 1345293 . + .   367-2064
# chr GeneFinder gene 1346731 1347000 . + .    368-270
# chr GeneFinder gene 1347013 1347276 . + .    369-264
# chr GeneFinder gene 1347283 1348182 . + .    370-900
# chr GeneFinder gene 1354414 1356435 . + .   371-2022
# chr GeneFinder gene 1359454 1360272 . + .    372-819
# chr GeneFinder gene 1361254 1362168 . + .    373-915
# chr GeneFinder gene 1363141 1364148 . + .   374-1008
# chr GeneFinder gene 1367941 1368831 . + .    375-891
# chr GeneFinder gene 1368844 1369833 . + .    376-990
# chr GeneFinder gene 1372792 1373991 . + .   377-1200
# chr GeneFinder gene 1375765 1376295 . + .    378-531
# chr GeneFinder gene 1376824 1377177 . + .    379-354
# chr GeneFinder gene 1379605 1380852 . + .   380-1248
# chr GeneFinder gene 1382020 1382430 . + .    381-411
# chr GeneFinder gene 1389133 1389441 . + .    382-309
# chr GeneFinder gene 1392118 1392639 . + .    383-522
# chr GeneFinder gene 1392643 1394007 . + .   384-1365
# chr GeneFinder gene 1394776 1395288 . + .    385-513
# chr GeneFinder gene 1397152 1397442 . + .    386-291
# chr GeneFinder gene 1398496 1398960 . + .    387-465
# chr GeneFinder gene 1400062 1400739 . + .    388-678
# chr GeneFinder gene 1401772 1403466 . + .   389-1695
# chr GeneFinder gene 1403668 1404492 . + .    390-825
# chr GeneFinder gene 1412644 1413789 . + .   391-1146
# chr GeneFinder gene 1416067 1417416 . + .   392-1350
# chr GeneFinder gene 1428940 1429569 . + .    393-630
# chr GeneFinder gene 1440169 1440549 . + .    394-381
# chr GeneFinder gene 1441249 1441788 . + .    395-540
# chr GeneFinder gene 1442872 1443618 . + .    396-747
# chr GeneFinder gene 1444129 1445298 . + .   397-1170
# chr GeneFinder gene 1445638 1446336 . + .    398-699
# chr GeneFinder gene 1448506 1449132 . + .    399-627
# chr GeneFinder gene 1449214 1450587 . + .   400-1374
# chr GeneFinder gene 1451371 1453284 . + .   401-1914
# chr GeneFinder gene 1455019 1456029 . + .   402-1011
# chr GeneFinder gene 1459375 1459650 . + .    403-276
# chr GeneFinder gene 1467805 1469862 . + .   404-2058
# chr GeneFinder gene 1480849 1481451 . + .    405-603
# chr GeneFinder gene 1486045 1486926 . + .    406-882
# chr GeneFinder gene 1487038 1487514 . + .    407-477
# chr GeneFinder gene 1488973 1489683 . + .    408-711
# chr GeneFinder gene 1489753 1490877 . + .   409-1125
# chr GeneFinder gene 1492261 1492803 . + .    410-543
# chr GeneFinder gene 1493914 1494171 . + .    411-258
# chr GeneFinder gene 1496155 1497174 . + .   412-1020
# chr GeneFinder gene 1498966 1499439 . + .    413-474
# chr GeneFinder gene 1504282 1505415 . + .   414-1134
# chr GeneFinder gene 1505416 1506108 . + .    415-693
# chr GeneFinder gene 1509337 1511163 . + .   416-1827
# chr GeneFinder gene 1511461 1511889 . + .    417-429
# chr GeneFinder gene 1512373 1513995 . + .   418-1623
# chr GeneFinder gene 1515934 1516302 . + .    419-369
# chr GeneFinder gene 1523305 1523619 . + .    420-315
# chr GeneFinder gene 1531870 1533282 . + .   421-1413
# chr GeneFinder gene 1537441 1538238 . + .    422-798
# chr GeneFinder gene 1543816 1544085 . + .    423-270
# chr GeneFinder gene 1549594 1550793 . + .   424-1200
# chr GeneFinder gene 1551385 1552314 . + .    425-930
# chr GeneFinder gene 1560466 1561536 . + .   426-1071
# chr GeneFinder gene 1564063 1564395 . + .    427-333
# chr GeneFinder gene 1566334 1567419 . + .   428-1086
# chr GeneFinder gene 1576384 1576710 . + .    429-327
# chr GeneFinder gene 1578376 1579995 . + .   430-1620
# chr GeneFinder gene 1584322 1586154 . + .   431-1833
# chr GeneFinder gene 1591540 1592631 . + .   432-1092
# chr GeneFinder gene 1594528 1595187 . + .    433-660
# chr GeneFinder gene 1595935 1596300 . + .    434-366
# chr GeneFinder gene 1599277 1603584 . + .   435-4308
# chr GeneFinder gene 1609327 1610163 . + .    436-837
# chr GeneFinder gene 1610371 1610862 . + .    437-492
# chr GeneFinder gene 1618933 1620330 . + .   438-1398
# chr GeneFinder gene 1623736 1626951 . + .   439-3216
# chr GeneFinder gene 1631095 1632159 . + .   440-1065
# chr GeneFinder gene 1632199 1633356 . + .   441-1158
# chr GeneFinder gene 1637965 1640637 . + .   442-2673
# chr GeneFinder gene 1641925 1642563 . + .    443-639
# chr GeneFinder gene 1646614 1646994 . + .    444-381
# chr GeneFinder gene 1653103 1653999 . + .    445-897
# chr GeneFinder gene 1656124 1656426 . + .    446-303
# chr GeneFinder gene 1656481 1658103 . + .   447-1623
# chr GeneFinder gene 1658242 1658904 . + .    448-663
# chr GeneFinder gene 1662547 1663548 . + .   449-1002
# chr GeneFinder gene 1663567 1664520 . + .    450-954
# chr GeneFinder gene 1667767 1668093 . + .    451-327
# chr GeneFinder gene 1670140 1671129 . + .    452-990
# chr GeneFinder gene 1672174 1673514 . + .   453-1341
# chr GeneFinder gene 1673620 1673892 . + .    454-273
# chr GeneFinder gene 1674259 1674645 . + .    455-387
# chr GeneFinder gene 1675171 1675902 . + .    456-732
# chr GeneFinder gene 1677625 1678218 . + .    457-594
# chr GeneFinder gene 1679977 1680258 . + .    458-282
# chr GeneFinder gene 1683655 1685736 . + .   459-2082
# chr GeneFinder gene 1685812 1687119 . + .   460-1308
# chr GeneFinder gene 1692124 1692450 . + .    461-327
# chr GeneFinder gene 1692496 1694106 . + .   462-1611
# chr GeneFinder gene 1694119 1695135 . + .   463-1017
# chr GeneFinder gene 1695877 1697193 . + .   464-1317
# chr GeneFinder gene 1699738 1700160 . + .    465-423
# chr GeneFinder gene 1700182 1700976 . + .    466-795
# chr GeneFinder gene 1702672 1703808 . + .   467-1137
# chr GeneFinder gene 1704445 1704870 . + .    468-426
# chr GeneFinder gene 1706599 1707681 . + .   469-1083
# chr GeneFinder gene 1710844 1711734 . + .    470-891
# chr GeneFinder gene 1712815 1714833 . + .   471-2019
# chr GeneFinder gene 1714855 1715325 . + .    472-471
# chr GeneFinder gene 1715344 1715973 . + .    473-630
# chr GeneFinder gene 1716493 1717257 . + .    474-765
# chr GeneFinder gene 1717933 1718673 . + .    475-741
# chr GeneFinder gene 1719802 1720524 . + .    476-723
# chr GeneFinder gene 1722967 1724022 . + .   477-1056
# chr GeneFinder gene 1724029 1725297 . + .   478-1269
# chr GeneFinder gene 1739383 1741500 . + .   479-2118
# chr GeneFinder gene 1741618 1742577 . + .    480-960
# chr GeneFinder gene 1742767 1743846 . + .   481-1080
# chr GeneFinder gene 1745263 1745865 . + .    482-603
# chr GeneFinder gene 1747249 1748337 . + .   483-1089
# chr GeneFinder gene 1748368 1749240 . + .    484-873
# chr GeneFinder gene 1749538 1751085 . + .   485-1548
# chr GeneFinder gene 1754785 1755510 . + .    486-726
# chr GeneFinder gene 1755628 1756857 . + .   487-1230
# chr GeneFinder gene 1760449 1760721 . + .    488-273
# chr GeneFinder gene 1760833 1761366 . + .    489-534
# chr GeneFinder gene 1767310 1768872 . + .   490-1563
# chr GeneFinder gene 1769935 1770195 . + .    491-261
# chr GeneFinder gene 1779490 1779804 . + .    492-315
# chr GeneFinder gene 1785133 1786107 . + .    493-975
# chr GeneFinder gene 1791418 1791972 . + .    494-555
# chr GeneFinder gene 1792012 1792761 . + .    495-750
# chr GeneFinder gene 1804333 1804605 . + .    496-273
# chr GeneFinder gene 1805677 1805931 . + .    497-255
# chr GeneFinder gene 1807921 1821537 . + .  498-13617
# chr GeneFinder gene 1821553 1834341 . + .  499-12789
# chr GeneFinder gene 1834507 1834824 . + .    500-318
# chr GeneFinder gene 1850890 1858521 . + .   501-7632
# chr GeneFinder gene 1858738 1859091 . + .    502-354
# chr GeneFinder gene 1863448 1864155 . + .    503-708
# chr GeneFinder gene 1864225 1864677 . + .    504-453
# chr GeneFinder gene 1868707 1869009 . + .    505-303
# chr GeneFinder gene 1871146 1872078 . + .    506-933
# chr GeneFinder gene 1874203 1875171 . + .    507-969
# chr GeneFinder gene 1875391 1876566 . + .   508-1176
# chr GeneFinder gene 1877959 1878366 . + .    509-408
# chr GeneFinder gene 1884238 1884879 . + .    510-642
# chr GeneFinder gene 1887352 1888743 . + .   511-1392
# chr GeneFinder gene 1888774 1890375 . + .   512-1602
# chr GeneFinder gene 1894114 1894383 . + .    513-270
# chr GeneFinder gene 1896424 1897839 . + .   514-1416
# chr GeneFinder gene 1899589 1900050 . + .    515-462
# chr GeneFinder gene 1901134 1901409 . + .    516-276
# chr GeneFinder gene 1905010 1905264 . + .    517-255
# chr GeneFinder gene 1907494 1909056 . + .   518-1563
# chr GeneFinder gene 1910200 1911381 . + .   519-1182
# chr GeneFinder gene 1912447 1912956 . + .    520-510
# chr GeneFinder gene 1917925 1918284 . + .    521-360
# chr GeneFinder gene 1922017 1922463 . + .    522-447
# chr GeneFinder gene 1924030 1924392 . + .    523-363
# chr GeneFinder gene 1924471 1924962 . + .    524-492
# chr GeneFinder gene 1929481 1929993 . + .    525-513
# chr GeneFinder gene 1930447 1930698 . + .    526-252
# chr GeneFinder gene 1930834 1931199 . + .    527-366
# chr GeneFinder gene 1931215 1931514 . + .    528-300
# chr GeneFinder gene 1933561 1935444 . + .   529-1884
# chr GeneFinder gene 1935598 1937868 . + .   530-2271
# chr GeneFinder gene 1938925 1940322 . + .   531-1398
# chr GeneFinder gene 1951972 1952307 . + .    532-336
# chr GeneFinder gene 1954930 1955265 . + .    533-336
# chr GeneFinder gene 1955887 1956195 . + .    534-309
# chr GeneFinder gene 1961011 1961376 . + .    535-366
# chr GeneFinder gene 1963726 1964058 . + .    536-333
# chr GeneFinder gene 1967557 1967832 . + .    537-276
# chr GeneFinder gene 1980073 1980438 . + .    538-366
# chr GeneFinder gene 1989310 1989570 . + .    539-261
# chr GeneFinder gene 1991866 1992156 . + .    540-291
# chr GeneFinder gene 1996396 1996722 . + .    541-327
# chr GeneFinder gene 2000401 2000760 . + .    542-360
# chr GeneFinder gene 2007526 2008515 . + .    543-990
# chr GeneFinder gene 2009875 2010165 . + .    544-291
# chr GeneFinder gene 2016154 2016555 . + .    545-402
# chr GeneFinder gene 2019421 2019726 . + .    546-306
# chr GeneFinder gene 2021581 2021970 . + .    547-390
# chr GeneFinder gene 2023258 2023614 . + .    548-357
# chr GeneFinder gene 2025400 2027442 . + .   549-2043
# chr GeneFinder gene 2027509 2027802 . + .    550-294
# chr GeneFinder gene 2031439 2032890 . + .   551-1452
# chr GeneFinder gene 2034715 2035782 . + .   552-1068
# chr GeneFinder gene 2045929 2046807 . + .    553-879
# chr GeneFinder gene 2048533 2049453 . + .    554-921
# chr GeneFinder gene 2062150 2063265 . + .   555-1116
# chr GeneFinder gene 2065042 2065377 . + .    556-336
# chr GeneFinder gene 2079079 2079603 . + .    557-525
# chr GeneFinder gene 2089396 2090454 . + .   558-1059
# chr GeneFinder gene 2097730 2097999 . + .    559-270
# chr GeneFinder gene 2100559 2102067 . + .   560-1509
# chr GeneFinder gene 2106433 2107455 . + .   561-1023
# chr GeneFinder gene 2108131 2108499 . + .    562-369
# chr GeneFinder gene 2109643 2109894 . + .    563-252
# chr GeneFinder gene 2112541 2112897 . + .    564-357
# chr GeneFinder gene 2119393 2120751 . + .   565-1359
# chr GeneFinder gene 2120767 2121615 . + .    566-849
# chr GeneFinder gene 2127457 2127708 . + .    567-252
# chr GeneFinder gene 2132740 2133039 . + .    568-300
# chr GeneFinder gene 2148676 2149077 . + .    569-402
# chr GeneFinder gene 2149084 2150037 . + .    570-954
# chr GeneFinder gene 2152888 2153169 . + .    571-282
# chr GeneFinder gene 2181985 2182323 . + .    572-339
# chr GeneFinder gene 2190937 2191218 . + .    573-282
# chr GeneFinder gene 2191939 2192253 . + .    574-315
# chr GeneFinder gene 2195971 2196264 . + .    575-294
# chr GeneFinder gene 2223940 2224200 . + .    576-261
# chr GeneFinder gene 2229373 2229885 . + .    577-513
# chr GeneFinder gene 2229988 2230908 . + .    578-921
# chr GeneFinder gene 2232682 2234202 . + .   579-1521
# chr GeneFinder gene 2234926 2235669 . + .    580-744
# chr GeneFinder gene 2235694 2236230 . + .    581-537
# chr GeneFinder gene 2237806 2238201 . + .    582-396
# chr GeneFinder gene 2238436 2239086 . + .    583-651
# chr GeneFinder gene 2241508 2241765 . + .    584-258
# chr GeneFinder gene 2242414 2243631 . + .   585-1218
# chr GeneFinder gene 2245114 2246148 . + .   586-1035
# chr GeneFinder gene 2247883 2248335 . + .    587-453
# chr GeneFinder gene 2248417 2249100 . + .    588-684
# chr GeneFinder gene 2257000 2259459 . + .   589-2460
# chr GeneFinder gene 2259709 2260296 . + .    590-588
# chr GeneFinder gene 2260333 2262267 . + .   591-1935
# chr GeneFinder gene 2263489 2264592 . + .   592-1104
# chr GeneFinder gene 2272156 2272491 . + .    593-336
# chr GeneFinder gene 2279971 2280867 . + .    594-897
# chr GeneFinder gene 2284846 2286408 . + .   595-1563
# chr GeneFinder gene 2286463 2287053 . + .    596-591
# chr GeneFinder gene 2288212 2288619 . + .    597-408
# chr GeneFinder gene 2292781 2293203 . + .    598-423
# chr GeneFinder gene 2303131 2303382 . + .    599-252
# chr GeneFinder gene 2305339 2306283 . + .    600-945
# chr GeneFinder gene 2308477 2308764 . + .    601-288
# chr GeneFinder gene 2318857 2319156 . + .    602-300
# chr GeneFinder gene 2329705 2330022 . + .    603-318
# chr GeneFinder gene 2337439 2337996 . + .    604-558
# chr GeneFinder gene 2340898 2341422 . + .    605-525
# chr GeneFinder gene 2341444 2344188 . + .   606-2745
# chr GeneFinder gene 2350426 2350686 . + .    607-261
# chr GeneFinder gene 2375917 2376195 . + .    608-279
# chr GeneFinder gene 2393806 2394072 . + .    609-267
# chr GeneFinder gene 2401213 2401518 . + .    610-306
# chr GeneFinder gene 2411086 2412663 . + .   611-1578
# chr GeneFinder gene 2414221 2414649 . + .    612-429
# chr GeneFinder gene 2419360 2419617 . + .    613-258
# chr GeneFinder gene 2423464 2423721 . + .    614-258
# chr GeneFinder gene 2425951 2426247 . + .    615-297
# chr GeneFinder gene 2426527 2426796 . + .    616-270
# chr GeneFinder gene 2436970 2437260 . + .    617-291
# chr GeneFinder gene 2445415 2445693 . + .    618-279
# chr GeneFinder gene 2452516 2452803 . + .    619-288
# chr GeneFinder gene 2453113 2453499 . + .    620-387
# chr GeneFinder gene 2459326 2460246 . + .    621-921
# chr GeneFinder gene 2460736 2461581 . + .    622-846
# chr GeneFinder gene 2466721 2467953 . + .   623-1233
# chr GeneFinder gene 2476960 2477730 . + .    624-771
# chr GeneFinder gene 2479495 2480625 . + .   625-1131
# chr GeneFinder gene 2482816 2483184 . + .    626-369
# chr GeneFinder gene 2493127 2493483 . + .    627-357
# chr GeneFinder gene 2499547 2499867 . + .    628-321
# chr GeneFinder gene 2500972 2501232 . + .    629-261
# chr GeneFinder gene 2511682 2511969 . + .    630-288
# chr GeneFinder gene 2512417 2512878 . + .    631-462
# chr GeneFinder gene 2516440 2517558 . + .   632-1119
# chr GeneFinder gene 2528887 2529618 . + .    633-732
# chr GeneFinder gene 2531038 2531307 . + .    634-270
# chr GeneFinder gene 2534086 2534379 . + .    635-294
# chr GeneFinder gene 2538910 2539188 . + .    636-279
# chr GeneFinder gene 2546875 2547138 . + .    637-264
# chr GeneFinder gene 2552620 2552988 . + .    638-369
# chr GeneFinder gene 2554228 2554542 . + .    639-315
# chr GeneFinder gene 2564566 2564883 . + .    640-318
# chr GeneFinder gene 2566816 2567115 . + .    641-300
# chr GeneFinder gene 2573647 2573898 . + .    642-252
# chr GeneFinder gene 2576152 2576406 . + .    643-255
# chr GeneFinder gene 2577349 2577606 . + .    644-258
# chr GeneFinder gene 2578981 2579328 . + .    645-348
# chr GeneFinder gene 2583889 2584146 . + .    646-258
# chr GeneFinder gene 2588701 2589000 . + .    647-300
# chr GeneFinder gene 2590804 2591385 . + .    648-582
# chr GeneFinder gene 2593000 2593254 . + .    649-255
# chr GeneFinder gene 2594602 2594988 . + .    650-387
# chr GeneFinder gene 2620666 2621640 . + .    651-975
# chr GeneFinder gene 2624284 2624649 . + .    652-366
# chr GeneFinder gene 2637760 2638116 . + .    653-357
# chr GeneFinder gene 2638339 2638701 . + .    654-363
# chr GeneFinder gene 2640526 2640876 . + .    655-351
# chr GeneFinder gene 2651632 2652354 . + .    656-723
# chr GeneFinder gene 2656498 2656767 . + .    657-270
# chr GeneFinder gene 2659243 2660340 . + .   658-1098
# chr GeneFinder gene 2670733 2671086 . + .    659-354
# chr GeneFinder gene 2675074 2675790 . + .    660-717
# chr GeneFinder gene 2675962 2676360 . + .    661-399
# chr GeneFinder gene 2695090 2695542 . + .    662-453
# chr GeneFinder gene 2701105 2701356 . + .    663-252
# chr GeneFinder gene 2705398 2706615 . + .   664-1218
# chr GeneFinder gene 2710195 2710485 . + .    665-291
# chr GeneFinder gene 2716384 2716692 . + .    666-309
# chr GeneFinder gene 2721778 2722644 . + .    667-867
# chr GeneFinder gene 2725837 2726727 . + .    668-891
# chr GeneFinder gene 2738308 2739105 . + .    669-798
# chr GeneFinder gene 2744863 2745129 . + .    670-267
# chr GeneFinder gene 2745841 2746158 . + .    671-318
# chr GeneFinder gene 2749660 2750475 . + .    672-816
# chr GeneFinder gene 2753134 2753433 . + .    673-300
# chr GeneFinder gene 2753452 2754588 . + .   674-1137
# chr GeneFinder gene 2754820 2755119 . + .    675-300
# chr GeneFinder gene 2768827 2769654 . + .    676-828
# chr GeneFinder gene 2769850 2770350 . + .    677-501
# chr GeneFinder gene 2770390 2770704 . + .    678-315
# chr GeneFinder gene 2778445 2778699 . + .    679-255
# chr GeneFinder gene 2786725 2787099 . + .    680-375
# chr GeneFinder gene 2787274 2787600 . + .    681-327
# chr GeneFinder gene 2791735 2792016 . + .    682-282
# chr GeneFinder gene 2793862 2794146 . + .    683-285
# chr GeneFinder gene 2802358 2803086 . + .    684-729
# chr GeneFinder gene 2803108 2803929 . + .    685-822
# chr GeneFinder gene 2803990 2804640 . + .    686-651
# chr GeneFinder gene 2810488 2810805 . + .    687-318
# chr GeneFinder gene 2812336 2813601 . + .   688-1266
# chr GeneFinder gene 2821309 2821629 . + .    689-321
# chr GeneFinder gene 2821735 2822193 . + .    690-459
# chr GeneFinder gene 2822206 2822676 . + .    691-471
# chr GeneFinder gene 2827369 2827821 . + .    692-453
# chr GeneFinder gene 2827828 2828130 . + .    693-303
# chr GeneFinder gene 2831626 2831922 . + .    694-297
# chr GeneFinder gene 2839429 2839689 . + .    695-261
# chr GeneFinder gene 2840110 2840757 . + .    696-648
# chr GeneFinder gene 2840905 2841300 . + .    697-396
# chr GeneFinder gene 2843224 2843562 . + .    698-339
# chr GeneFinder gene 2845549 2845821 . + .    699-273
# chr GeneFinder gene 2849554 2850756 . + .   700-1203
# chr GeneFinder gene 2853601 2853936 . + .    701-336
# chr GeneFinder gene 2855563 2855850 . + .    702-288
# chr GeneFinder gene 2857018 2857278 . + .    703-261
# chr GeneFinder gene 2879359 2879613 . + .    704-255
# chr GeneFinder gene 2893570 2893878 . + .    705-309
# chr GeneFinder gene 2894527 2894829 . + .    706-303
# chr GeneFinder gene 2897668 2898123 . + .    707-456
# chr GeneFinder gene 2898361 2898747 . + .    708-387
# chr GeneFinder gene 2898931 2899752 . + .    709-822
# chr GeneFinder gene 2900404 2900877 . + .    710-474
# chr GeneFinder gene 2901106 2901366 . + .    711-261
# chr GeneFinder gene 2903968 2904270 . + .    712-303
# chr GeneFinder gene 2907040 2907342 . + .    713-303
# chr GeneFinder gene 2909584 2909949 . + .    714-366
# chr GeneFinder gene 2914441 2914701 . + .    715-261
# chr GeneFinder gene 2930149 2930412 . + .    716-264
# chr GeneFinder gene 2931958 2933082 . + .   717-1125
# chr GeneFinder gene 2933176 2934597 . + .   718-1422
# chr GeneFinder gene 2937151 2937441 . + .    719-291
# chr GeneFinder gene 2938423 2938680 . + .    720-258
# chr GeneFinder gene 2942920 2943204 . + .    721-285
# chr GeneFinder gene 2951203 2951508 . + .    722-306
# chr GeneFinder gene 2953795 2954460 . + .    723-666
# chr GeneFinder gene 2961001 2961252 . + .    724-252
# chr GeneFinder gene 2963680 2963961 . + .    725-282
# chr GeneFinder gene 2975611 2975931 . + .    726-321
# chr GeneFinder gene 2986666 2986935 . + .    727-270
# chr GeneFinder gene 2988067 2988339 . + .    728-273
# chr GeneFinder gene 2996980 2997282 . + .    729-303
# chr GeneFinder gene 3009037 3009864 . + .    730-828
# chr GeneFinder gene 3012208 3012474 . + .    731-267
# chr GeneFinder gene 3015367 3015801 . + .    732-435
# chr GeneFinder gene 3018466 3018786 . + .    733-321
# chr GeneFinder gene 3019108 3019476 . + .    734-369
# chr GeneFinder gene 3023818 3024075 . + .    735-258
# chr GeneFinder gene 3028297 3029634 . + .   736-1338
# chr GeneFinder gene 3041365 3042555 . + .   737-1191
# chr GeneFinder gene 3043438 3043794 . + .    738-357
# chr GeneFinder gene 3050638 3051045 . + .    739-408
# chr GeneFinder gene 3057367 3057645 . + .    740-279
# chr GeneFinder gene 3061918 3062241 . + .    741-324
# chr GeneFinder gene 3063466 3063843 . + .    742-378
# chr GeneFinder gene 3066445 3067386 . + .    743-942
# chr GeneFinder gene 3068908 3070206 . + .   744-1299
# chr GeneFinder gene 3075343 3076629 . + .   745-1287
# chr GeneFinder gene 3078676 3079020 . + .    746-345
# chr GeneFinder gene 3106210 3106995 . + .    747-786
# chr GeneFinder gene 3114205 3114468 . + .    748-264
# chr GeneFinder gene 3120964 3121548 . + .    749-585
# chr GeneFinder gene 3123271 3124005 . + .    750-735
# chr GeneFinder gene 3132346 3133374 . + .   751-1029
# chr GeneFinder gene 3133387 3134169 . + .    752-783
# chr GeneFinder gene 3134767 3135342 . + .    753-576
# chr GeneFinder gene 3135379 3135684 . + .    754-306
# chr GeneFinder gene 3140806 3141846 . + .   755-1041
# chr GeneFinder gene 3155443 3155703 . + .    756-261
# chr GeneFinder gene 3155725 3157011 . + .   757-1287
# chr GeneFinder gene 3163237 3163704 . + .    758-468
# chr GeneFinder gene 3168274 3168537 . + .    759-264
# chr GeneFinder gene 3174136 3174453 . + .    760-318
# chr GeneFinder gene 3174727 3175026 . + .    761-300
# chr GeneFinder gene 3182659 3183195 . + .    762-537
# chr GeneFinder gene 3183373 3183687 . + .    763-315
# chr GeneFinder gene 3186763 3187305 . + .    764-543
# chr GeneFinder gene 3189118 3189510 . + .    765-393
# chr GeneFinder gene 3197077 3197892 . + .    766-816
# chr GeneFinder gene 3200992 3201315 . + .    767-324
# chr GeneFinder gene 3206509 3206817 . + .    768-309
# chr GeneFinder gene 3206926 3207315 . + .    769-390
# chr GeneFinder gene 3215353 3215691 . + .    770-339
# chr GeneFinder gene 3217804 3218118 . + .    771-315
# chr GeneFinder gene 3218854 3219840 . + .    772-987
# chr GeneFinder gene 3227581 3228402 . + .    773-822
# chr GeneFinder gene 3228778 3229941 . + .   774-1164
# chr GeneFinder gene 3233917 3235785 . + .   775-1869
# chr GeneFinder gene 3237157 3238758 . + .   776-1602
# chr GeneFinder gene 3245992 3246309 . + .    777-318
# chr GeneFinder gene 3246739 3249003 . + .   778-2265
# chr GeneFinder gene 3249427 3249768 . + .    779-342
# chr GeneFinder gene 3251248 3251724 . + .    780-477
# chr GeneFinder gene 3251992 3252366 . + .    781-375
# chr GeneFinder gene 3253294 3253557 . + .    782-264
# chr GeneFinder gene 3262027 3262437 . + .    783-411
# chr GeneFinder gene 3275440 3275781 . + .    784-342
# chr GeneFinder gene 3276955 3278223 . + .   785-1269
# chr GeneFinder gene 3284563 3284847 . + .    786-285
# chr GeneFinder gene 3287467 3287721 . + .    787-255
# chr GeneFinder gene 3289468 3289725 . + .    788-258
# chr GeneFinder gene 3290434 3290757 . + .    789-324
# chr GeneFinder gene 3292123 3292446 . + .    790-324
# chr GeneFinder gene 3295543 3295797 . + .    791-255
# chr GeneFinder gene 3300175 3300780 . + .    792-606
# chr GeneFinder gene 3305815 3306138 . + .    793-324
# chr GeneFinder gene 3307360 3307905 . + .    794-546
# chr GeneFinder gene 3313096 3313389 . + .    795-294
# chr GeneFinder gene 3323980 3324381 . + .    796-402
# chr GeneFinder gene 3327772 3328131 . + .    797-360
# chr GeneFinder gene 3328621 3330357 . + .   798-1737
# chr GeneFinder gene 3330556 3331851 . + .   799-1296
# chr GeneFinder gene 3332506 3332772 . + .    800-267
# chr GeneFinder gene 3339223 3339474 . + .    801-252
# chr GeneFinder gene 3342139 3342453 . + .    802-315
# chr GeneFinder gene 3344047 3344979 . + .    803-933
# chr GeneFinder gene 3349954 3350301 . + .    804-348
# chr GeneFinder gene 3361987 3362244 . + .    805-258
# chr GeneFinder gene 3369406 3369741 . + .    806-336
# chr GeneFinder gene 3374956 3376581 . + .   807-1626
# chr GeneFinder gene 3377893 3378780 . + .    808-888
# chr GeneFinder gene 3382633 3383475 . + .    809-843
# chr GeneFinder gene 3386398 3387753 . + .   810-1356
# chr GeneFinder gene 3389887 3390174 . + .    811-288
# chr GeneFinder gene 3397525 3397875 . + .    812-351
# chr GeneFinder gene 3398731 3399015 . + .    813-285
# chr GeneFinder gene 3417430 3417696 . + .    814-267
# chr GeneFinder gene 3417805 3418068 . + .    815-264
# chr GeneFinder gene 3418474 3419421 . + .    816-948
# chr GeneFinder gene 3425254 3426054 . + .    817-801
# chr GeneFinder gene 3428560 3428937 . + .    818-378
# chr GeneFinder gene 3429706 3430035 . + .    819-330
# chr GeneFinder gene 3456667 3457074 . + .    820-408
# chr GeneFinder gene 3457366 3457941 . + .    821-576
# chr GeneFinder gene 3461161 3461529 . + .    822-369
# chr GeneFinder gene 3463051 3463317 . + .    823-267
# chr GeneFinder gene 3463525 3464067 . + .    824-543
# chr GeneFinder gene 3480919 3481251 . + .    825-333
# chr GeneFinder gene 3482197 3482580 . + .    826-384
# chr GeneFinder gene 3483946 3484254 . + .    827-309
# chr GeneFinder gene 3486751 3487080 . + .    828-330
# chr GeneFinder gene 3487936 3488199 . + .    829-264
# chr GeneFinder gene 3490399 3490731 . + .    830-333
# chr GeneFinder gene 3495010 3495321 . + .    831-312
# chr GeneFinder gene 3496243 3496554 . + .    832-312
# chr GeneFinder gene 3498193 3498480 . + .    833-288
# chr GeneFinder gene 3500386 3501597 . + .   834-1212
# chr GeneFinder gene 3520156 3520416 . + .    835-261
# chr GeneFinder gene 3525388 3525660 . + .    836-273
# chr GeneFinder gene 3526876 3527157 . + .    837-282
# chr GeneFinder gene 3530101 3530559 . + .    838-459
# chr GeneFinder gene 3530635 3532104 . + .   839-1470
# chr GeneFinder gene 3534439 3534708 . + .    840-270
# chr GeneFinder gene 3537598 3537924 . + .    841-327
# chr GeneFinder gene 3542281 3542580 . + .    842-300
# chr GeneFinder gene 3544660 3545604 . + .    843-945
# chr GeneFinder gene 3555388 3555894 . + .    844-507
# chr GeneFinder gene 3563356 3563688 . + .    845-333
# chr GeneFinder gene 3591976 3592233 . + .    846-258
# chr GeneFinder gene 3597289 3598020 . + .    847-732
# chr GeneFinder gene 3602074 3602547 . + .    848-474
# chr GeneFinder gene 3604993 3605502 . + .    849-510
# chr GeneFinder gene 3606880 3607143 . + .    850-264
# chr GeneFinder gene 3609496 3609960 . + .    851-465
# chr GeneFinder gene 3613144 3613512 . + .    852-369
# chr GeneFinder gene 3615769 3618288 . + .   853-2520
# chr GeneFinder gene 3618400 3618933 . + .    854-534
# chr GeneFinder gene 3618964 3620298 . + .   855-1335
# chr GeneFinder gene 3628363 3628671 . + .    856-309
# chr GeneFinder gene 3646612 3647406 . + .    857-795
# chr GeneFinder gene 3649558 3649845 . + .    858-288
# chr GeneFinder gene 3651907 3652167 . + .    859-261
# chr GeneFinder gene 3665629 3666507 . + .    860-879
# chr GeneFinder gene 3670021 3670293 . + .    861-273
# chr GeneFinder gene 3681370 3682140 . + .    862-771
# chr GeneFinder gene 3691372 3692496 . + .   863-1125
# chr GeneFinder gene 3698155 3698508 . + .    864-354
# chr GeneFinder gene 3707836 3708132 . + .    865-297
# chr GeneFinder gene 3716596 3716928 . + .    866-333
# chr GeneFinder gene 3719113 3719565 . + .    867-453
# chr GeneFinder gene 3720889 3721401 . + .    868-513
# chr GeneFinder gene 3722005 3722541 . + .    869-537
# chr GeneFinder gene 3723523 3724335 . + .    870-813
# chr GeneFinder gene 3724744 3725049 . + .    871-306
# chr GeneFinder gene 3733852 3735462 . + .   872-1611
# chr GeneFinder gene 3738628 3738882 . + .    873-255
# chr GeneFinder gene 3742351 3743220 . + .    874-870
# chr GeneFinder gene 3744349 3745413 . + .   875-1065
# chr GeneFinder gene 3755434 3755712 . + .    876-279
# chr GeneFinder gene 3756790 3758004 . + .   877-1215
# chr GeneFinder gene 3761107 3761700 . + .    878-594
# chr GeneFinder gene 3762622 3764112 . + .   879-1491
# chr GeneFinder gene 3780529 3781035 . + .    880-507
# chr GeneFinder gene 3789763 3790071 . + .    881-309
# chr GeneFinder gene 3790162 3790428 . + .    882-267
# chr GeneFinder gene 3792373 3792633 . + .    883-261
# chr GeneFinder gene 3793633 3794040 . + .    884-408
# chr GeneFinder gene 3797929 3798198 . + .    885-270
# chr GeneFinder gene 3802819 3803088 . + .    886-270
# chr GeneFinder gene 3803887 3804249 . + .    887-363
# chr GeneFinder gene 3806194 3806460 . + .    888-267
# chr GeneFinder gene 3806602 3806904 . + .    889-303
# chr GeneFinder gene 3813628 3813891 . + .    890-264
# chr GeneFinder gene 3830704 3831480 . + .    891-777
# chr GeneFinder gene 3834070 3834528 . + .    892-459
# chr GeneFinder gene 3836338 3837669 . + .   893-1332
# chr GeneFinder gene 3838552 3839862 . + .   894-1311
# chr GeneFinder gene 3842107 3842415 . + .    895-309
# chr GeneFinder gene 3845677 3845952 . + .    896-276
# chr GeneFinder gene 3846055 3847146 . + .   897-1092
# chr GeneFinder gene 3847348 3847821 . + .    898-474
# chr GeneFinder gene 3863914 3864330 . + .    899-417
# chr GeneFinder gene 3866596 3867360 . + .    900-765
# chr GeneFinder gene 3867517 3868272 . + .    901-756
# chr GeneFinder gene 3872971 3873468 . + .    902-498
# chr GeneFinder gene 3878617 3878907 . + .    903-291
# chr GeneFinder gene 3881296 3881682 . + .    904-387
# chr GeneFinder gene 3885058 3885351 . + .    905-294
# ...
# chr GeneFinder gene 1364605 1364861 . - .   5558-261
# chr GeneFinder gene 1362799 1363058 . - .   5559-264
# chr GeneFinder gene 1356169 1356446 . - .   5560-282
# chr GeneFinder gene 1353166 1353440 . - .   5561-279
# chr GeneFinder gene 1350484 1351097 . - .   5562-618
# chr GeneFinder gene 1349470 1350467 . - .  5563-1002
# chr GeneFinder gene 1346455 1346819 . - .   5564-369
# chr GeneFinder gene 1342513 1342796 . - .   5565-288
# chr GeneFinder gene 1333189 1333643 . - .   5566-459
# chr GeneFinder gene 1332454 1332767 . - .   5567-318
# chr GeneFinder gene 1329700 1330118 . - .   5568-423
# chr GeneFinder gene 1320379 1320647 . - .   5569-273
# chr GeneFinder gene 1317745 1318109 . - .   5570-369
# chr GeneFinder gene 1313842 1314317 . - .   5571-480
# chr GeneFinder gene 1304881 1305140 . - .   5572-264
# chr GeneFinder gene 1296622 1297604 . - .   5573-987
# chr GeneFinder gene 1291741 1292105 . - .   5574-369
# chr GeneFinder gene 1284373 1284767 . - .   5575-399
# chr GeneFinder gene 1282573 1283027 . - .   5576-459
# chr GeneFinder gene 1279516 1280501 . - .   5577-990
# chr GeneFinder gene 1277653 1278047 . - .   5578-399
# chr GeneFinder gene 1276339 1276841 . - .   5579-507
# chr GeneFinder gene 1262701 1262957 . - .   5580-261
# chr GeneFinder gene 1249444 1249886 . - .   5581-447
# chr GeneFinder gene 1248751 1249073 . - .   5582-327
# chr GeneFinder gene 1245535 1245854 . - .   5583-324
# chr GeneFinder gene 1235914 1236482 . - .   5584-573
# chr GeneFinder gene 1233616 1234439 . - .   5585-828
# chr GeneFinder gene 1224646 1224923 . - .   5586-282
# chr GeneFinder gene 1222783 1223048 . - .   5587-270
# chr GeneFinder gene 1218115 1219148 . - .  5588-1038
# chr GeneFinder gene 1206781 1207184 . - .   5589-408
# chr GeneFinder gene 1201435 1201721 . - .   5590-291
# chr GeneFinder gene 1196587 1197074 . - .   5591-492
# chr GeneFinder gene 1195327 1195655 . - .   5592-333
# chr GeneFinder gene 1192081 1192388 . - .   5593-312
# chr GeneFinder gene 1189669 1190024 . - .   5594-360
# chr GeneFinder gene 1186732 1187141 . - .   5595-414
# chr GeneFinder gene 1183945 1184522 . - .   5596-582
# chr GeneFinder gene 1179631 1179941 . - .   5597-315
# chr GeneFinder gene 1174138 1174808 . - .   5598-675
# chr GeneFinder gene 1170475 1171448 . - .   5599-978
# chr GeneFinder gene 1169797 1170068 . - .   5600-276
# chr GeneFinder gene 1168201 1168835 . - .   5601-639
# chr GeneFinder gene 1163758 1164053 . - .   5602-300
# chr GeneFinder gene 1159213 1159718 . - .   5603-510
# chr GeneFinder gene 1158607 1158914 . - .   5604-312
# chr GeneFinder gene 1148746 1149143 . - .   5605-402
# chr GeneFinder gene 1147249 1147568 . - .   5606-324
# chr GeneFinder gene 1140109 1140413 . - .   5607-309
# chr GeneFinder gene 1134217 1134986 . - .   5608-774
# chr GeneFinder gene 1130920 1131971 . - .  5609-1056
# chr GeneFinder gene 1126402 1127450 . - .  5610-1053
# chr GeneFinder gene 1124008 1124288 . - .   5611-285
# chr GeneFinder gene 1121038 1121396 . - .   5612-363
# chr GeneFinder gene 1117381 1117763 . - .   5613-387
# chr GeneFinder gene 1111927 1112483 . - .   5614-561
# chr GeneFinder gene 1110481 1111916 . - .  5615-1440
# chr GeneFinder gene 1109920 1110209 . - .   5616-294
# chr GeneFinder gene 1108738 1109315 . - .   5617-582
# chr GeneFinder gene 1100275 1100618 . - .   5618-348
# chr GeneFinder gene 1094743 1095092 . - .   5619-354
# chr GeneFinder gene 1092772 1093745 . - .   5620-978
# chr GeneFinder gene 1082872 1083218 . - .   5621-351
# chr GeneFinder gene 1075291 1076366 . - .  5622-1080
# chr GeneFinder gene 1074940 1075214 . - .   5623-279
# chr GeneFinder gene 1073773 1074038 . - .   5624-270
# chr GeneFinder gene 1067212 1067915 . - .   5625-708
# chr GeneFinder gene 1062994 1063268 . - .   5626-279
# chr GeneFinder gene 1060990 1061324 . - .   5627-339
# chr GeneFinder gene 1060429 1060850 . - .   5628-426
# chr GeneFinder gene 1059205 1060418 . - .  5629-1218
# chr GeneFinder gene 1052164 1053251 . - .  5630-1092
# chr GeneFinder gene 1050445 1050710 . - .   5631-270
# chr GeneFinder gene 1048603 1048931 . - .   5632-333
# chr GeneFinder gene 1040863 1041707 . - .   5633-849
# chr GeneFinder gene 1039384 1039679 . - .   5634-300
# chr GeneFinder gene 1038919 1039343 . - .   5635-429
# chr GeneFinder gene 1037308 1037708 . - .   5636-405
# chr GeneFinder gene 1036246 1036640 . - .   5637-399
# chr GeneFinder gene 1034029 1034417 . - .   5638-393
# chr GeneFinder gene 1030150 1030637 . - .   5639-492
# chr GeneFinder gene 1022803 1023068 . - .   5640-270
# chr GeneFinder gene 1019551 1019822 . - .   5641-276
# chr GeneFinder gene 1017085 1018466 . - .  5642-1386
# chr GeneFinder gene 1013413 1013849 . - .   5643-441
# chr GeneFinder gene 1005607 1005890 . - .   5644-288
# chr GeneFinder gene 1001821 1002110 . - .   5645-294
# chr GeneFinder gene  995626  996530 . - .   5646-909
# chr GeneFinder gene  972364  972647 . - .   5647-288
# chr GeneFinder gene  967231  967856 . - .   5648-630
# chr GeneFinder gene  966037  966383 . - .   5649-351
# chr GeneFinder gene  963136  963422 . - .   5650-291
# chr GeneFinder gene  954238  954506 . - .   5651-273
# chr GeneFinder gene  942451  943625 . - .  5652-1179
# chr GeneFinder gene  941170  942227 . - .  5653-1062
# chr GeneFinder gene  935617  935909 . - .   5654-297
# chr GeneFinder gene  934459  935438 . - .   5655-984
# chr GeneFinder gene  928114  928400 . - .   5656-291
# chr GeneFinder gene  920833  921275 . - .   5657-447
# chr GeneFinder gene  918100  918428 . - .   5658-333
# chr GeneFinder gene  916126  916604 . - .   5659-483
# chr GeneFinder gene  913582  913919 . - .   5660-342
# chr GeneFinder gene  908728  909065 . - .   5661-342
# chr GeneFinder gene  908422  908714 . - .   5662-297
# chr GeneFinder gene  898144  898535 . - .   5663-396
# chr GeneFinder gene  891019  891296 . - .   5664-282
# chr GeneFinder gene  890020  890279 . - .   5665-264
# chr GeneFinder gene  888145  889289 . - .  5666-1149
# chr GeneFinder gene  886777  887294 . - .   5667-522
# chr GeneFinder gene  886225  886763 . - .   5668-543
# chr GeneFinder gene  882967  883277 . - .   5669-315
# chr GeneFinder gene  876574  876905 . - .   5670-336
# chr GeneFinder gene  874237  874574 . - .   5671-342
# chr GeneFinder gene  868009  869126 . - .  5672-1122
# chr GeneFinder gene  867166  868004 . - .   5673-843
# chr GeneFinder gene  863056  863471 . - .   5674-420
# chr GeneFinder gene  860305  861491 . - .  5675-1191
# chr GeneFinder gene  848635  850172 . - .  5676-1542
# chr GeneFinder gene  846184  847277 . - .  5677-1098
# chr GeneFinder gene  844132  844463 . - .   5678-336
# chr GeneFinder gene  839737  840482 . - .   5679-750
# chr GeneFinder gene  839341  839651 . - .   5680-315
# chr GeneFinder gene  831274  831569 . - .   5681-300
# chr GeneFinder gene  824716  825779 . - .  5682-1068
# chr GeneFinder gene  819313  820529 . - .  5683-1221
# chr GeneFinder gene  817333  817646 . - .   5684-318
# chr GeneFinder gene  803902  804206 . - .   5685-309
# chr GeneFinder gene  791464  792530 . - .  5686-1071
# chr GeneFinder gene  786196  786509 . - .   5687-318
# chr GeneFinder gene  785545  785903 . - .   5688-363
# chr GeneFinder gene  778885  779186 . - .   5689-306
# chr GeneFinder gene  777490  777761 . - .   5690-276
# chr GeneFinder gene  776917  777164 . - .   5691-252
# chr GeneFinder gene  773533  773831 . - .   5692-303
# chr GeneFinder gene  772570  773201 . - .   5693-636
# chr GeneFinder gene  768166  768827 . - .   5694-666
# chr GeneFinder gene  760423  760733 . - .   5695-315
# chr GeneFinder gene  758329  758606 . - .   5696-282
# chr GeneFinder gene  747556  749567 . - .  5697-2016
# chr GeneFinder gene  738997  739556 . - .   5698-564
# chr GeneFinder gene  738667  738944 . - .   5699-282
# chr GeneFinder gene  731956  732821 . - .   5700-870
# chr GeneFinder gene  726037  726665 . - .   5701-633
# chr GeneFinder gene  719509  719798 . - .   5702-294
# chr GeneFinder gene  716782  718355 . - .  5703-1578
# chr GeneFinder gene  713557  713804 . - .   5704-252
# chr GeneFinder gene  711166  711512 . - .   5705-351
# chr GeneFinder gene  710332  710696 . - .   5706-369
# chr GeneFinder gene  709717  710030 . - .   5707-318
# chr GeneFinder gene  699439  699728 . - .   5708-294
# chr GeneFinder gene  698302  698591 . - .   5709-294
# chr GeneFinder gene  696130  696392 . - .   5710-267
# chr GeneFinder gene  695599  695867 . - .   5711-273
# chr GeneFinder gene  694702  695183 . - .   5712-486
# chr GeneFinder gene  692200  692474 . - .   5713-279
# chr GeneFinder gene  683464  685007 . - .  5714-1548
# chr GeneFinder gene  664777  667262 . - .  5715-2490
# chr GeneFinder gene  658561  658814 . - .   5716-258
# chr GeneFinder gene  644530  646454 . - .  5717-1929
# chr GeneFinder gene  639622  639935 . - .   5718-318
# chr GeneFinder gene  639049  639344 . - .   5719-300
# chr GeneFinder gene  633925  634286 . - .   5720-366
# chr GeneFinder gene  628537  628802 . - .   5721-270
# chr GeneFinder gene  627811  628106 . - .   5722-300
# chr GeneFinder gene  622810  623288 . - .   5723-483
# chr GeneFinder gene  614887  615620 . - .   5724-738
# chr GeneFinder gene  613789  614114 . - .   5725-330
# chr GeneFinder gene  612193  612818 . - .   5726-630
# chr GeneFinder gene  608248  608810 . - .   5727-567
# chr GeneFinder gene  604738  606377 . - .  5728-1644
# chr GeneFinder gene  602443  602729 . - .   5729-291
# chr GeneFinder gene  595111  596000 . - .   5730-894
# chr GeneFinder gene  586630  587069 . - .   5731-444
# chr GeneFinder gene  585157  585722 . - .   5732-570
# chr GeneFinder gene  582538  583454 . - .   5733-921
# chr GeneFinder gene  574108  574463 . - .   5734-360
# chr GeneFinder gene  573454  574022 . - .   5735-573
# chr GeneFinder gene  570373  571232 . - .   5736-864
# chr GeneFinder gene  539014  539303 . - .   5737-294
# chr GeneFinder gene  537046  537293 . - .   5738-252
# chr GeneFinder gene  532930  533303 . - .   5739-378
# chr GeneFinder gene  529507  530609 . - .  5740-1107
# chr GeneFinder gene  527485  527771 . - .   5741-291
# chr GeneFinder gene  524674  524933 . - .   5742-264
# chr GeneFinder gene  510310  510620 . - .   5743-315
# chr GeneFinder gene  509839  510167 . - .   5744-333
# chr GeneFinder gene  501079  501449 . - .   5745-375
# chr GeneFinder gene  498523  498779 . - .   5746-261
# chr GeneFinder gene  496648  497696 . - .  5747-1053
# chr GeneFinder gene  495742  496559 . - .   5748-822
# chr GeneFinder gene  492991  493499 . - .   5749-513
# chr GeneFinder gene  491149  492422 . - .  5750-1278
# chr GeneFinder gene  487333  487700 . - .   5751-372
# chr GeneFinder gene  481951  482198 . - .   5752-252
# chr GeneFinder gene  478237  478523 . - .   5753-291
# chr GeneFinder gene  472729  473039 . - .   5754-315
# chr GeneFinder gene  470959  471551 . - .   5755-597
# chr GeneFinder gene  467500  467747 . - .   5756-252
# chr GeneFinder gene  463498  463781 . - .   5757-288
# chr GeneFinder gene  461350  461672 . - .   5758-327
# chr GeneFinder gene  456556  456803 . - .   5759-252
# chr GeneFinder gene  455434  455720 . - .   5760-291
# chr GeneFinder gene  454654  455285 . - .   5761-636
# chr GeneFinder gene  450676  451094 . - .   5762-423
# chr GeneFinder gene  446803  448424 . - .  5763-1626
# chr GeneFinder gene  446176  446654 . - .   5764-483
# chr GeneFinder gene  437476  438581 . - .  5765-1110
# chr GeneFinder gene  435013  435392 . - .   5766-384
# chr GeneFinder gene  432385  432767 . - .   5767-387
# chr GeneFinder gene  428206  428480 . - .   5768-279
# chr GeneFinder gene  427567  427877 . - .   5769-315
# chr GeneFinder gene  424906  426362 . - .  5770-1461
# chr GeneFinder gene  424210  424886 . - .   5771-681
# chr GeneFinder gene  423529  423809 . - .   5772-285
# chr GeneFinder gene  422575  422876 . - .   5773-306
# chr GeneFinder gene  415603  415856 . - .   5774-258
# chr GeneFinder gene  414757  415028 . - .   5775-276
# chr GeneFinder gene  411580  412469 . - .   5776-894
# chr GeneFinder gene  409210  410003 . - .   5777-798
# chr GeneFinder gene  407374  407696 . - .   5778-327
# chr GeneFinder gene  403501  403961 . - .   5779-465
# chr GeneFinder gene  393637  393890 . - .   5780-258
# chr GeneFinder gene  374605  375158 . - .   5781-558
# chr GeneFinder gene  371731  372041 . - .   5782-315
# chr GeneFinder gene  371203  371468 . - .   5783-270
# chr GeneFinder gene  363673  363989 . - .   5784-321
# chr GeneFinder gene  355414  355736 . - .   5785-327
# chr GeneFinder gene  353902  355349 . - .  5786-1452
# chr GeneFinder gene  351844  352694 . - .   5787-855
# chr GeneFinder gene  350860  351758 . - .   5788-903
# chr GeneFinder gene  347551  347987 . - .   5789-441
# chr GeneFinder gene  345826  346220 . - .   5790-399
# chr GeneFinder gene  340615  341645 . - .  5791-1035
# chr GeneFinder gene  336094  337430 . - .  5792-1341
# chr GeneFinder gene  335263  335594 . - .   5793-336
# chr GeneFinder gene  334192  334568 . - .   5794-381
# chr GeneFinder gene  332443  333977 . - .  5795-1539
# chr GeneFinder gene  331783  332234 . - .   5796-456
# chr GeneFinder gene  331009  331295 . - .   5797-291
# chr GeneFinder gene  330133  330521 . - .   5798-393
# chr GeneFinder gene  324040  325187 . - .  5799-1152
# chr GeneFinder gene  314326  314636 . - .   5800-315
# chr GeneFinder gene  310882  311699 . - .   5801-822
# chr GeneFinder gene  305221  305474 . - .   5802-258
# chr GeneFinder gene  299440  300500 . - .  5803-1065
# chr GeneFinder gene  298759  299246 . - .   5804-492
# chr GeneFinder gene  293977  294377 . - .   5805-405
# chr GeneFinder gene  290134  290696 . - .   5806-567
# chr GeneFinder gene  288655  290090 . - .  5807-1440
# chr GeneFinder gene  281134  281456 . - .   5808-327
# chr GeneFinder gene  278563  278867 . - .   5809-309
# chr GeneFinder gene  273067  273548 . - .   5810-486
# chr GeneFinder gene  270598  271163 . - .   5811-570
# chr GeneFinder gene  267925  268229 . - .   5812-309
# chr GeneFinder gene  264193  265253 . - .  5813-1065
# chr GeneFinder gene  261658  262601 . - .   5814-948
# chr GeneFinder gene  260125  261533 . - .  5815-1413
# chr GeneFinder gene  256825  257570 . - .   5816-750
# chr GeneFinder gene  253261  253607 . - .   5817-351
# chr GeneFinder gene  242836  243704 . - .   5818-873
# chr GeneFinder gene  234982  235283 . - .   5819-306
# chr GeneFinder gene  230821  231077 . - .   5820-261
# chr GeneFinder gene  224077  224930 . - .   5821-858
# chr GeneFinder gene  202549  203399 . - .   5822-855
# chr GeneFinder gene  191185  192098 . - .   5823-918
# chr GeneFinder gene  188410  189569 . - .  5824-1164
# chr GeneFinder gene  186454  188378 . - .  5825-1929
# chr GeneFinder gene  180346  181352 . - .  5826-1011
# chr GeneFinder gene  175681  175994 . - .   5827-318
# chr GeneFinder gene  175108  175403 . - .   5828-300
# chr GeneFinder gene  164503  164798 . - .   5829-300
# chr GeneFinder gene  159781  160196 . - .   5830-420
# chr GeneFinder gene  157957  158216 . - .   5831-264
# chr GeneFinder gene  153325  153593 . - .   5832-273
# chr GeneFinder gene  145966  146288 . - .   5833-327
# chr GeneFinder gene  143335  143765 . - .   5834-435
# chr GeneFinder gene  140458  140708 . - .   5835-255
# chr GeneFinder gene  133147  133619 . - .   5836-477
# chr GeneFinder gene  127291  127547 . - .   5837-261
# chr GeneFinder gene  124810  125063 . - .   5838-258
# chr GeneFinder gene  124309  124580 . - .   5839-276
# chr GeneFinder gene  122428  122756 . - .   5840-333
# chr GeneFinder gene  115639  115913 . - .   5841-279
# chr GeneFinder gene  104617  105083 . - .   5842-471
# chr GeneFinder gene  103876  104402 . - .   5843-531
# chr GeneFinder gene   89593   89978 . - .   5844-390
# chr GeneFinder gene   85759   86183 . - .   5845-429
# chr GeneFinder gene   84319   84614 . - .   5846-300
# chr GeneFinder gene   81673   82136 . - .   5847-468
# chr GeneFinder gene   71992   72281 . - .   5848-294
# chr GeneFinder gene   60094   60347 . - .   5849-258
# chr GeneFinder gene   53209   53480 . - .   5850-276
# chr GeneFinder gene   51778   52229 . - .   5851-456
# chr GeneFinder gene   50479   50744 . - .   5852-270
# chr GeneFinder gene   26935   27308 . - .   5853-378
# chr GeneFinder gene   22498   23147 . - .   5854-654
# chr GeneFinder gene   15832   16127 . - .   5855-300
# chr GeneFinder gene   14176   14489 . - .   5856-318
# chr GeneFinder gene   13603   13898 . - .   5857-300
# chr GeneFinder gene    3799    4067 . - .   5858-273

# %% [markdown]
# ## Sort ORFs dataframe

# %%
def sort_orfs_by_start(orfs_df):
    """
    Sorts ORFs DataFrame by the 'start' column in ascending order.

    Parameters:
        orfs_df (pd.DataFrame): DataFrame containing ORF information.

    Returns:
        pd.DataFrame: Sorted DataFrame by 'start' column.
    """
    sorted_orfs_df = orfs_df.sort_values(by='start').reset_index(drop=True)
    return sorted_orfs_df

# Example usage:
sorted_orfs_df = sort_orfs_by_start(orfs_df)
print(sorted_orfs_df.head())
# Out:
#   seqid      source  type  start   end score strand phase unique_id
# 0   chr  GeneFinder  gene    326  1750     .      +     .  977-1425
# 1   chr  GeneFinder  gene   1816  3075     .      +     .    1-1260
# 2   chr  GeneFinder  gene   3554  4549     .      +     .   978-996
# 3   chr  GeneFinder  gene   3799  4067     .      -     .  5858-273
# 4   chr  GeneFinder  gene   4867  6783     .      +     .    2-1917

# %% [markdown]
# ## Save Sorted ORFs to GFF3 format

# %%
sorted_orfs_df.to_csv("output_genes.sorted.gff3", sep='\t', header=False, index=False)
print("Gene locations saved to sorted_output_genes.gff3")
# Out:
# Gene locations saved to sorted output_genes.gff3

# %% [markdown]
# # Activity10
# 1. Implement Alternative Start Codons: Bacteria may use non-standard start codons like... <insert here>
# 2. Optimize ORF Search Parameters: Experiment with minimum ORF lengths, and the alternative start codons to assess prediction accuracy. Hint: check average values of gene length in GeneMarkS-2 output.
# 3. Export in Additional Formats: Extend export options (like BED format https://genome.ucsc.edu/FAQ/FAQformat.html) for compatibility with other bioinformatics tools.
# 4. Can you think of a metric that can be used to compare two gene prediction annotations, like GeneMarkS-2 and GeneFinder GFF3 output files?
# 5. Save your notebook with your reflections as markdownds,export it as PDF file (give a specific name, eg. Activity10 + your NAME) and send both to myCourses. For exporting as PDF from VisualStudio you may have to export it first as HTML, then to PDF.
